# %% [markdown]
# ASSIGNMENT-3
#
# Name: Shreyans Jain
#
# Registration Number: 21BCE6131

# %% [markdown]
# ### 1.Import the Libraries.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### 2.Importing the dataset.

# %%
df=pd.read_csv("titanic.csv")

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.corr()
# Out:
# <ipython-input-158-2f6f6606aa2c>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.005007 -0.035144  0.036847 -0.057527 -0.001652
# Survived       -0.005007  1.000000 -0.338481 -0.077221 -0.035322  0.081629
# Pclass         -0.035144 -0.338481  1.000000 -0.369226  0.083081  0.018443
# Age             0.036847 -0.077221 -0.369226  1.000000 -0.308247 -0.189119
# SibSp          -0.057527 -0.035322  0.083081 -0.308247  1.000000  0.414838
# Parch          -0.001652  0.081629  0.018443 -0.189119  0.414838  1.000000
# Fare            0.012658  0.257307 -0.549500  0.096067  0.159651  0.216225
#
#                  Fare
# PassengerId  0.012658
# Survived     0.257307
# Pclass      -0.549500
# ...

# %%
df.corr().Survived.sort_values(ascending=False)
# Out:
# <ipython-input-159-fe51b8bb09d5>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr().Survived.sort_values(ascending=False)
# Survived       1.000000
# Fare           0.257307
# Parch          0.081629
# PassengerId   -0.005007
# SibSp         -0.035322
# Age           -0.077221
# Pclass        -0.338481
# Name: Survived, dtype: float64

# %% [markdown]
# ### 3.Checking for Null Values.

# %%
df.isnull().any()
# Out:
# PassengerId    False
# Survived       False
# Pclass         False
# Name           False
# Sex            False
# Age             True
# SibSp          False
# Parch          False
# Ticket         False
# Fare           False
# Cabin           True
# Embarked        True
# dtype: bool

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
# Remove rows with missing values in specific columns
columns_with_missing_values = ['Age', 'Cabin', 'Embarked']
dataset = df.dropna(subset=columns_with_missing_values)

# %%
dataset.head()
# Out:
#     PassengerId  Survived  Pclass  \
# 1             2         1       1
# 3             4         1       1
# 6             7         0       1
# 10           11         1       3
# 11           12         1       1
#
#                                                  Name     Sex   Age  SibSp  \
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                             McCarthy, Mr. Timothy J    male  54.0      0
# 10                    Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                           Bonnell, Miss. Elizabeth  female  58.0      0
#
#     Parch    Ticket     Fare Cabin Embarked
# 1       0  PC 17599  71.2833   C85        C
# 3       0    113803  53.1000  C123        S
# 6       0     17463  51.8625   E46        S
# 10      1   PP 9549  16.7000    G6        S
# 11      0    113783  26.5500  C103        S

# %%
dataset.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %%
df.Embarked.nunique()
# Out:
# 3

# %%
df.Embarked.value_counts()
# Out:
# S    644
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %% [markdown]
# ### 4.Data Visualization.

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(data=dataset, x='Age', y='Fare', hue='Survived', palette='Set1')
plt.title('Scatter Plot of Fare vs. Age (Survived vs. Not Survived)')
plt.xlabel('Age')
plt.ylabel('Fare')
plt.legend(title='Survived', loc='upper right', labels=['No', 'Yes'])
plt.show()

# %%
sns.heatmap(df.corr(),annot=True)
# Out:
# <ipython-input-168-8df7bcac526d>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(),annot=True)
# <Axes: >

# %%
sns.pairplot(df)

# %%
sns.barplot(x=df["Embarked"],y=df["Survived"],ci=0)
# Out:
# <ipython-input-170-d5b0276940a6>:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', 0)` for the same effect.
#
#   sns.barplot(x=df["Embarked"],y=df["Survived"],ci=0)
# <Axes: xlabel='Embarked', ylabel='Survived'>

# %%
sns.histplot(data=df,x="Age",bins=20,kde=True)
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %%
gender_counts = dataset['Sex'].value_counts()
labels = gender_counts.index
sizes = gender_counts.values
colors = ['skyblue', 'lightcoral']

plt.figure(figsize=(4, 4))
plt.pie(sizes, labels=labels, colors=colors, autopct='%1.1f%%', startangle=140)
plt.title('Gender Distribution')
plt.axis('equal')
plt.show()

# %% [markdown]
# ### 5.Outlier Detection

# %%
dataset.head()
# Out:
#     PassengerId  Survived  Pclass  \
# 1             2         1       1
# 3             4         1       1
# 6             7         0       1
# 10           11         1       3
# 11           12         1       1
#
#                                                  Name     Sex   Age  SibSp  \
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                             McCarthy, Mr. Timothy J    male  54.0      0
# 10                    Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                           Bonnell, Miss. Elizabeth  female  58.0      0
#
#     Parch    Ticket     Fare Cabin Embarked
# 1       0  PC 17599  71.2833   C85        C
# 3       0    113803  53.1000  C123        S
# 6       0     17463  51.8625   E46        S
# 10      1   PP 9549  16.7000    G6        S
# 11      0    113783  26.5500  C103        S

# %%
sns.boxplot(df["Fare"])
# Out:
# <Axes: >

# %%
sns.boxplot(df["SibSp"])
# Out:
# <Axes: >

# %%
sns.boxplot(df["Age"])
# Out:
# <Axes: >

# %%
sns.boxplot(df["Pclass"])
# Out:
# <Axes: >

# %%
sns.boxplot(df["PassengerId"])
# Out:
# <Axes: >

# %%
sns.boxplot(df["Parch"])
# Out:
# <Axes: >

# %%
import pandas as pd
plt.figure(figsize=(12, 6))
sns.boxplot(data=dataset[['PassengerId', 'Survived', 'Pclass', 'Age', 'SibSp', 'Parch', 'Fare']], orient="h", palette="Set2")
threshold = 1.5
numerical_columns = ['PassengerId', 'Survived', 'Pclass', 'Age', 'SibSp', 'Parch', 'Fare']
for column in numerical_columns:
    Q1 = dataset[column].quantile(0.25)
    Q3 = dataset[column].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - threshold * IQR
    upper_bound = Q3 + threshold * IQR
    dataset = dataset[(dataset[column] >= lower_bound) & (dataset[column] <= upper_bound)]

# %%
dataset1.head()
# Out:
#     PassengerId  Survived  Pclass  \
# 1             2         1       1
# 3             4         1       1
# 6             7         0       1
# 10           11         1       3
# 11           12         1       1
#
#                                                  Name     Sex   Age  SibSp  \
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                             McCarthy, Mr. Timothy J    male  54.0      0
# 10                    Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                           Bonnell, Miss. Elizabeth  female  58.0      0
#
#     Parch    Ticket     Fare Cabin Embarked
# 1       0  PC 17599  71.2833   C85        C
# 3       0    113803  53.1000  C123        S
# 6       0     17463  51.8625   E46        S
# 10      1   PP 9549  16.7000    G6        S
# 11      0    113783  26.5500  C103        S

# %% [markdown]
# ## 5.Seperate dependent  and independent variables

# %%
X = dataset1.drop(columns=["Survived","Name","Ticket","Cabin","Embarked"])
Y = dataset1["Survived"]

# %%
X.head()
# Out:
#     PassengerId  Pclass     Sex   Age  SibSp  Parch     Fare
# 1             2       1  female  38.0      1      0  71.2833
# 3             4       1  female  35.0      1      0  53.1000
# 6             7       1    male  54.0      0      0  51.8625
# 10           11       3  female   4.0      1      1  16.7000
# 11           12       1  female  58.0      0      0  26.5500

# %%
Y
# Out:
# 1      1
# 3      1
# 6      0
# 10     1
# 11     1
#       ..
# 871    1
# 872    0
# 879    1
# 887    1
# 889    1
# Name: Survived, Length: 167, dtype: int64

# %%
dataset.shape
# Out:
# (142, 12)

# %%
X.shape
# Out:
# (167, 7)

# %%
Y.shape
# Out:
# (167,)

# %% [markdown]
# ## 6.Encoding

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
X["Sex"] = le.fit_transform(X["Sex"])

# %%
X["Sex"].head()
# Out:
# 1     0
# 3     0
# 6     1
# 10    0
# 11    0
# Name: Sex, dtype: int64

# %%
print(le.classes_)
# Out:
# ['female' 'male']

# %%
mapping=dict(zip(le.classes_,range(len(le.classes_))))
mapping
# Out:
# {'female': 0, 'male': 1}

# %% [markdown]
# ### 8.Feature Scaling

# %%
from sklearn.preprocessing import MinMaxScaler
ms=MinMaxScaler()

# %%
X_Scaled=ms.fit_transform(X)

# %%
X_Scaled=pd.DataFrame(ms.fit_transform(X),columns=X.columns)

# %%
X_Scaled.head()
# Out:
#    PassengerId  Pclass  Sex       Age  SibSp  Parch      Fare
# 0     0.000000     0.0  0.0  0.468892    0.5    0.0  0.432369
# 1     0.002252     0.0  0.0  0.430956    0.5    0.0  0.322078
# 2     0.005631     0.0  1.0  0.671219    0.0    0.0  0.314572
# 3     0.010135     1.0  0.0  0.038948    0.5    0.5  0.101294
# 4     0.011261     0.0  0.0  0.721801    0.0    0.0  0.161039

# %% [markdown]
# ### 9.Train test split

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(X_Scaled,Y,test_size =0.2,random_state =0)

# %%
print(x_train.shape,x_test.shape,y_train.shape,y_test.shape)
# Out:
# (133, 7) (34, 7) (133,) (34,)
